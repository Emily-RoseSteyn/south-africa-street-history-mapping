# %%
import osmnx as ox
ox.citation()
# Out:
# @article{boeing_osmnx_2017,
#     title = {{OSMnx}: {New} {Methods} for {Acquiring}, {Constructing}, {Analyzing}, and {Visualizing} {Complex} {Street} {Networks}},
#     volume = {65},
#     doi = {10.1016/j.compenvurbsys.2017.05.004},
#     number = {126-139},
#     journal = {Computers, Environment and Urban Systems},
#     author = {Boeing, Geoff},
#     year = {2017},
#     pages = {126--139}
# }

# %%
kensington_graph = ox.graph_from_place('Kensington, City of Johannesburg, South Africa', network_type="drive")
ox.plot_graph(kensington_graph)
# Out:
# (<Figure size 800x800 with 1 Axes>, <Axes: >)

# %%
# Prepare data
data = []
for _, _, _, ddata in kensington_graph.edges(keys=True, data=True): # added ww
    data.append(ddata)
print(len(data))

data
# Out:
# 872
# [{'osmid': 87361206,
#   'lanes': '4',
#   'ref': 'R24',
#   'name': 'Albertina Sisulu Road',
#   'highway': 'primary',
#   'maxspeed': '60',
#   'oneway': False,
#   'reversed': False,
#   'length': 45.163},
#  {'osmid': 87361206,
#   'lanes': '4',
#   'ref': 'R24',
#   'name': 'Albertina Sisulu Road',
#   'highway': 'primary',
#   'maxspeed': '60',
#   'oneway': False,
#   'reversed': True,
#   'length': 40.507},
#  {'osmid': 26372461,
#   'lanes': '2',
#   'name': 'Cavan Street',
#   'highway': 'residential',
#   'oneway': False,
#   'reversed': True,
#   'length': 88.156,
#   'geometry': <LINESTRING (28.085 -26.191, 28.085 -26.192, 28.085 -26.192)>},
#  {'osmid': 23060545,
#   'lanes': '2',
#   'name': '1st Street',
#   'highway': 'residential',
#   'oneway': False,
#   'reversed': False,
#   'length': 7.771},
#  {'osmid': [765781197, 767333415],
#   'oneway': True,
#   'lanes': '2',
#   'ref': 'R24',
#   'name': 'Albertina Sisulu Road',
#   'highway': 'primary',
#   'maxspeed': '60',
#   'reversed': False,
#   'length': 31.393,
#   'geometry': <LINESTRING (28.077 -26.194, 28.076 -26.194, 28.076 -26.195)>},
#  {'osmid': 542568178,
#   'lanes': '2',
#   'name': 'Arethusa Street',
#   'highway': 'residential',
#   'oneway': False,
#   'reversed': False,
#   'length': 67.635},
#  {'osmid': 12071997,
#   'lanes': '2',
#   'name': 'Sovereign Street',
#   'highway': 'tertiary',
#   'oneway': False,
#   'reversed': True,
#   'length': 77.756},
#  {'osmid': 34035749,
#   'lanes': '2',
#   'name': 'Oxford Road',
#   'highway': 'residential',
#   'oneway': False,
#   'reversed': False,
#   'length': 344.056},
#  {'osmid': 12071997,
#   'lanes': '2',
#   'name': 'Sovereign Street',
#   'highway': 'tertiary',
#   'oneway': False,
#   'reversed': False,
#   'length': 125.08099999999999,
#   'geometry': <LINESTRING (28.119 -26.193, 28.119 -26.193, 28.119 -26.192)>},
#  {'osmid': 12069308,
#   'lanes': '2',
#   'name': 'Pandora Road',
#   'highway': 'tertiary',
#   'oneway': False,
#   'reversed': False,
#   'length': 145.253},
#  {'osmid': 12071997,
#   'lanes': '2',
#   'name': 'Sovereign Street',
#   'highway': 'tertiary',
#   'oneway': False,
#   'reversed': False,
#   'length': 78.057,
#   'geometry': <LINESTRING (28.12 -26.198, 28.12 -26.198, 28.12 -26.197)>},
#  {'osmid': 12069308,
#   'lanes': '2',
#   'name': 'Pandora Road',
#   'highway': 'tertiary',
#   'oneway': False,
#   'reversed': False,
#   'length': 28.037},
#  {'osmid': 12069308,
#   'lanes': '2',
#   'name': 'Pandora Road',
#   'highway': 'tertiary',
#   'oneway': False,
#   'reversed': True,
#   'length': 4.824},
#  {'osmid': 12069308,
#   'lanes': '2',
#   'name': 'Pandora Road',
#   'highway': 'tertiary',
#   'oneway': False,
#   'reversed': False,
#   'length': 52.915},
#  {'osmid': 12069308,
#   'lanes': '2',
#   'name': 'Pandora Road',
#   'highway': 'tertiary',
#   'oneway': False,
#   'reversed': True,
#   'length': 68.76},
#  {'osmid': 34035502,
#   'lanes': '2',
#   'name': 'Royal Oak Street',
#   'highway': 'residential',
#   'oneway': False,
#   'reversed': False,
#   'length': 26.866},
#  {'osmid': 12069308,
#   'lanes': '2',
#   'name': 'Pandora Road',
#   'highway': 'tertiary',
#   'oneway': False,
#   'reversed': False,
#   'length': 102.672},
#  {'osmid': 12069308,
#   'lanes': '2',
#   'name': 'Pandora Road',
#   'highway': 'tertiary',
#   'oneway': False,
#   'reversed': True,
#   'length': 55.89},
#  {'osmid': 12069308,
#   'lanes': '2',
#   'name': 'Pandora Road',
#   'highway': 'tertiary',
#   'oneway': False,
#   'reversed': True,
#   'length': 104.50999999999999,
#   'geometry': <LINESTRING (28.114 -26.198, 28.115 -26.198, 28.115 -26.198)>},
#  {'osmid': 34035742,
#   'lanes': '2',
#   'name': 'Gloucester Road',
#   'highway': 'residential',
#   'oneway': False,
#   'reversed': False,
#   'length': 289.629,
#   'geometry': <LINESTRING (28.114 -26.198, 28.114 -26.198, 28.114 -26.198, 28.114 -26.198,...>},
#  {'osmid': 597485085,
#   'lanes': '2',
#   'ref': 'M33',
#   'name': 'Pandora Road',
#   'highway': 'tertiary',
#   'oneway': False,
#   'reversed': False,
#   'length': 105.236,
#   'geometry': <LINESTRING (28.114 -26.198, 28.114 -26.198, 28.114 -26.198, 28.113 -26.198)>},
#  {'osmid': 597485083,
#   'oneway': True,
#   'lanes': '1',
#   'ref': 'M33',
#   'name': 'Queen Street',
#   'highway': 'tertiary',
#   'reversed': False,
#   'length': 6.349},
#  {'osmid': 34035444,
#   'lanes': '2',
#   'name': 'Buckingham Road',
#   'highway': 'residential',
#   'oneway': False,
#   'reversed': False,
#   'length': 394.058},
#  {'osmid': 496129466,
#   'lanes': '2',
#   'ref': 'M33',
#   'name': 'Queen Street',
#   'highway': 'tertiary',
#   'oneway': False,
#   'reversed': True,
#   'length': 34.74},
#  {'osmid': 496129466,
#   'lanes': '2',
#   'ref': 'M33',
#   'name': 'Queen Street',
#   'highway': 'tertiary',
#   'oneway': False,
#   'reversed': False,
#   'length': 77.42500000000001,
#   'geometry': <LINESTRING (28.113 -26.197, 28.113 -26.197, 28.112 -26.196)>},
#  {'osmid': 34035749,
#   'lanes': '2',
#   'name': 'Oxford Road',
#   'highway': 'residential',
#   'oneway': False,
#   'reversed': True,
#   'length': 393.794,
#   'geometry': <LINESTRING (28.112 -26.196, 28.115 -26.195, 28.116 -26.195)>},
#  {'osmid': 496129466,
#   'lanes': '2',
#   'ref': 'M33',
#   'name': 'Queen Street',
#   'highway': 'tertiary',
#   'oneway': False,
#   'reversed': False,
#   'length': 144.563,
#   'geometry': <LINESTRING (28.112 -26.196, 28.112 -26.196, 28.112 -26.195)>},
#  {'osmid': 496129466,
#   'lanes': '2',
#   'ref': 'M33',
#   'name': 'Queen Street',
#   'highway': 'tertiary',
#   'oneway': False,
#   'reversed': True,
#   'length': 77.42500000000001,
#   'geometry': <LINESTRING (28.112 -26.196, 28.113 -26.197, 28.113 -26.197)>},
#  {'osmid': 616779440,
#   'lanes': '2',
#   'name': 'Oxford Road',
#   'highway': 'residential',
#   'oneway': False,
#   'reversed': False,
#   'length': 293.348,
#   'geometry': <LINESTRING (28.112 -26.196, 28.11 -26.198, 28.11 -26.198, 28.11 -26.198, 28...>},
#  {'osmid': 34035514,
#   'lanes': '2',
#   'name': 'Derby Road',
#   'highway': 'residential',
#   'oneway': False,
#   'reversed': True,
#   'length': 393.601},
#  {'osmid': 496129466,
#   'lanes': '2',
#   'ref': 'M33',
#   'name': 'Queen Street',
#   'highway': 'tertiary',
#   'oneway': False,
#   'reversed': False,
#   'length': 146.269},
#  {'osmid': 34035514,
#   'lanes': '2',
#   'name': 'Derby Road',
#   'highway': 'residential',
#   'oneway': False,
#   'reversed': False,
#   'length': 397.13599999999997,
#   'geometry': <LINESTRING (28.11 -26.193, 28.108 -26.194, 28.107 -26.195)>},
#  {'osmid': 496129466,
#   'lanes': '2',
#   'ref': 'M33',
#   'name': 'Queen Street',
#   'highway': 'tertiary',
#   'oneway': False,
#   'reversed': True,
#   'length': 145.475,
#   'geometry': <LINESTRING (28.11 -26.193, 28.111 -26.194, 28.111 -26.194)>},
#  {'osmid': 624791800,
#   'lanes': '3',
#   'ref': 'M33',
#   'name': 'Queen Street',
#   'highway': 'secondary',
#   'oneway': False,
#   'reversed': False,
#   'length': 9.903},
#  {'osmid': [744422808, 624791802],
#   'oneway': True,
#   'lanes': '2',
#   'ref': 'R22',
#   'name': 'Langermann Drive',
#   'highway': 'secondary',
#   'reversed': False,
#   'length': 135.359,
#   'geometry': <LINESTRING (28.108 -26.189, 28.108 -26.189, 28.108 -26.19, 28.107 -26.19, 2...>},
#  {'osmid': [496129466, 624791805],
#   'lanes': ['3', '2'],
#   'ref': 'M33',
#   'name': 'Queen Street',
#   'highway': 'tertiary',
#   'oneway': False,
#   'reversed': True,
#   'length': 150.38099999999997,
#   'geometry': <LINESTRING (28.108 -26.189, 28.109 -26.19, 28.109 -26.19, 28.109 -26.19, 28...>},
#  {'osmid': 12070124,
#   'oneway': False,
#   'lanes': '4',
#   'ref': 'R22',
#   'name': 'Langermann Drive',
#   'highway': 'secondary',
#   'reversed': False,
#   'length': 77.678},
#  {'osmid': 12070124,
#   'oneway': False,
#   'lanes': '4',
#   'ref': 'R22',
#   'name': 'Langermann Drive',
#   'highway': 'secondary',
#   'reversed': True,
#   'length': 80.789},
#  {'osmid': 34035826,
#   'lanes': '2',
#   'name': 'Phoenix Street',
#   'highway': 'residential',
#   'oneway': False,
#   'reversed': False,
#   'length': 228.562},
#  {'osmid': 34035826,
#   'lanes': '2',
#   'name': 'Phoenix Street',
#   'highway': 'residential',
#   'oneway': False,
#   'reversed': True,
#   'length': 301.307},
#  {'osmid': 625102380,
#   'oneway': False,
#   'lanes': '4',
#   'name': 'Kitchener Avenue',
#   'highway': 'secondary',
#   'reversed': False,
#   'length': 10.656},
#  {'osmid': 625102381,
#   'oneway': True,
#   'lanes': '2',
#   'name': 'Milner Crescent',
#   'highway': 'secondary',
#   'reversed': False,
#   'length': 88.538},
#  {'osmid': 31013874,
#   'oneway': False,
#   'lanes': '4',
#   'name': 'Kitchener Avenue',
#   'highway': 'secondary',
#   'reversed': True,
#   'length': 77.946,
#   'geometry': <LINESTRING (28.097 -26.195, 28.097 -26.195, 28.097 -26.195, 28.096 -26.195)>},
#  {'osmid': 625102384,
#   'lanes': '4',
#   'name': 'Roberts Avenue',
#   'highway': 'secondary',
#   'oneway': False,
#   'reversed': True,
#   'length': 33.1},
#  {'osmid': 625102386,
#   'lanes': '4',
#   'name': 'Roberts Avenue',
#   'highway': 'secondary',
#   'oneway': False,
#   'reversed': False,
#   'length': 47.432},
#  {'osmid': 34036047,
#   'oneway': False,
#   'lanes': '2',
#   'name': 'Lancaster Street',
#   'highway': 'residential',
#   'maxspeed': '40',
#   'reversed': False,
#   'length': 152.49599999999998,
#   'geometry': <LINESTRING (28.093 -26.197, 28.092 -26.196, 28.092 -26.196, 28.092 -26.196,...>},
#  {'osmid': 12071997,
#   'lanes': '2',
#   'name': 'Sovereign Street',
#   'highway': 'tertiary',
#   'oneway': False,
#   'reversed': True,
#   'length': 105.982},
#  {'osmid': 12072035,
#   'oneway': False,
#   'lanes': '2',
#   'name': 'Leicester Road',
#   'highway': 'residential',
#   'reversed': True,
#   'length': 418.866},
#  {'osmid': 625102388,
#   'lanes': '4',
#   'name': 'Roberts Avenue',
#   'highway': 'secondary',
#   'oneway': False,
#   'reversed': False,
#   'length': 74.929},
#  {'osmid': 179565396,
#   'lanes': '2',
#   'name': 'Juno Street',
#   'highway': 'tertiary',
#   'oneway': False,
#   'reversed': False,
#   'length': 520.668,
#   'geometry': <LINESTRING (28.087 -26.198, 28.087 -26.197, 28.087 -26.197, 28.087 -26.196,...>},
#  {'osmid': 625102388,
#   'lanes': '4',
#   'name': 'Roberts Avenue',
#   'highway': 'secondary',
#   'oneway': False,
#   'reversed': True,
#   'length': 68.946,
#   'geometry': <LINESTRING (28.087 -26.198, 28.088 -26.198, 28.088 -26.198)>},
#  {'osmid': 624806817,
#   'lanes': '4',
#   'name': 'Roberts Avenue',
#   'highway': 'secondary',
#   'oneway': False,
#   'reversed': False,
#   'length': 75.401},
#  {'osmid': 34036238,
#   'lanes': '2',
#   'name': 'Good Hope Street',
#   'highway': 'residential',
#   'oneway': False,
#   'reversed': False,
#   'length': 210.716,
#   'geometry': <LINESTRING (28.082 -26.199, 28.082 -26.199, 28.082 -26.198, 28.082 -26.198)>},
#  {'osmid': 34036238,
#   'lanes': '2',
#   'name': 'Good Hope Street',
#   'highway': 'residential',
#   'oneway': False,
#   'reversed': True,
#   'length': 89.11099999999999,
#   'geometry': <LINESTRING (28.082 -26.199, 28.082 -26.2, 28.082 -26.2)>},
#  {'osmid': 624806823,
#   'lanes': '4',
#   'name': 'Roberts Avenue',
#   'highway': 'secondary',
#   'oneway': False,
#   'reversed': True,
#   'length': 82.167,
#   'geometry': <LINESTRING (28.082 -26.199, 28.082 -26.199, 28.083 -26.199, 28.083 -26.199,...>},
#  {'osmid': 4339878,
#   'oneway': True,
#   'lanes': '2',
#   'ref': 'R24',
#   'name': 'Albertina Sisulu Road',
#   'highway': 'primary',
#   'maxspeed': '60',
#   'reversed': False,
#   'length': 56.103},
#  {'osmid': 23060541,
#   'lanes': '2',
#   'name': 'Lang Street',
#   'highway': 'residential',
#   'oneway': False,
#   'reversed': True,
#   'length': 6.585},
#  {'osmid': 4339878,
#   'oneway': True,
#   'lanes': '2',
#   'ref': 'R24',
#   'name': 'Albertina Sisulu Road',
#   'highway': 'primary',
#   'maxspeed': '60',
#   'reversed': False,
#   'length': 65.072},
#  {'osmid': 23060561,
#   'lanes': '2',
#   'name': 'Cambrian Street',
#   'highway': 'residential',
#   'oneway': False,
#   'reversed': False,
#   'length': 6.973},
#  {'osmid': 23060560,
#   'lanes': '2',
#   'name': 'Cressey Street',
#   'highway': 'residential',
#   'oneway': False,
#   'reversed': False,
#   'length': 7.026},
#  {'osmid': [765781194, 4339878],
#   'oneway': True,
#   'lanes': '2',
#   'ref': 'R24',
#   'name': 'Albertina Sisulu Road',
#   'highway': 'primary',
#   'maxspeed': '60',
#   'reversed': False,
#   'length': 31.651,
#   'geometry': <LINESTRING (28.076 -26.194, 28.076 -26.194, 28.076 -26.194)>},
#  {'osmid': 23060552,
#   'lanes': '2',
#   'name': 'Dasher Street',
#   'highway': 'residential',
#   'oneway': False,
#   'reversed': False,
#   'length': 162.999},
#  {'osmid': 23060552,
#   'lanes': '2',
#   'name': 'Dasher Street',
#   'highway': 'residential',
#   'oneway': False,
#   'reversed': True,
#   'length': 8.08},
#  {'osmid': 765781196,
#   'oneway': True,
#   'lanes': '2',
#   'ref': 'R24',
#   'name': 'Albertina Sisulu Road',
#   'highway': 'primary',
#   'maxspeed': '60',
#   'reversed': False,
#   'length': 107.834,
#   'geometry': <LINESTRING (28.078 -26.194, 28.077 -26.194, 28.077 -26.194)>},
#  {'osmid': 23060551,
#   'lanes': '2',
#   'name': 'Durham Street',
#   'highway': 'residential',
#   'oneway': False,
#   'reversed': False,
#   'length': 188.262},
#  {'osmid': 23060551,
#   'lanes': '2',
#   'name': 'Durham Street',
#   'highway': 'residential',
#   'oneway': False,
#   'reversed': True,
#   'length': 8.078},
#  {'osmid': 765781196,
#   'oneway': True,
#   'lanes': '2',
#   'ref': 'R24',
#   'name': 'Albertina Sisulu Road',
#   'highway': 'primary',
#   'maxspeed': '60',
#   'reversed': False,
#   'length': 66.626},
#  {'osmid': 23060549,
#   'lanes': '2',
#   'name': 'Essex Street',
#   'highway': 'residential',
#   'oneway': False,
#   'reversed': True,
#   'length': 7.804},
#  {'osmid': 23060549,
#   'lanes': '2',
#   'name': 'Essex Street',
#   'highway': 'residential',
#   'oneway': False,
#   'reversed': False,
#   'length': 252.81799999999998,
#   'geometry': <LINESTRING (28.079 -26.193, 28.08 -26.194, 28.08 -26.195)>},
#  {'osmid': 765781196,
#   'oneway': True,
#   'lanes': '2',
#   'ref': 'R24',
#   'name': 'Albertina Sisulu Road',
#   'highway': 'primary',
#   'maxspeed': '60',
#   'reversed': False,
#   'length': 66.55499999999999,
#   'geometry': <LINESTRING (28.079 -26.193, 28.079 -26.193, 28.079 -26.194)>},
#  {'osmid': 87361206,
#   'lanes': '4',
#   'ref': 'R24',
#   'name': 'Albertina Sisulu Road',
#   'highway': 'primary',
#   'maxspeed': '60',
#   'oneway': False,
#   'reversed': False,
#   'length': 65.899},
#  {'osmid': 87361206,
#   'lanes': '4',
#   'ref': 'R24',
#   'name': 'Albertina Sisulu Road',
#   'highway': 'primary',
#   'maxspeed': '60',
#   'oneway': False,
#   'reversed': True,
#   'length': 64.385},
#  {'osmid': 23060553,
#   'lanes': '2',
#   'name': 'Ferret Street',
#   'highway': 'residential',
#   'oneway': False,
#   'reversed': False,
#   'length': 208.594,
#   'geometry': <LINESTRING (28.08 -26.193, 28.081 -26.194, 28.081 -26.195)>},
#  {'osmid': 87361206,
#   'lanes': '4',
#   'ref': 'R24',
#   'name': 'Albertina Sisulu Road',
#   'highway': 'primary',
#   'maxspeed': '60',
#   'oneway': False,
#   'reversed': False,
#   'length': 27.299},
#  {'osmid': 87361206,
#   'lanes': '4',
#   'ref': 'R24',
#   'name': 'Albertina Sisulu Road',
#   'highway': 'primary',
#   'maxspeed': '60',
#   'oneway': False,
#   'reversed': True,
#   'length': 43.005},
#  {'osmid': 23060549,
#   'lanes': '2',
#   'name': 'Essex Street',
#   'highway': 'residential',
#   'oneway': False,
#   'reversed': True,
#   'length': 252.81799999999998,
#   'geometry': <LINESTRING (28.08 -26.195, 28.08 -26.194, 28.079 -26.193)>},
#  {'osmid': 23060550,
#   'lanes': '2',
#   'name': 'Emerald Street',
#   'highway': 'residential',
#   'oneway': False,
#   'reversed': False,
#   'length': 201.117},
#  {'osmid': 23060550,
#   'lanes': '2',
#   'name': 'Emerald Street',
#   'highway': 'residential',
#   'oneway': False,
#   'reversed': True,
#   'length': 7.496},
#  {'osmid': 765781196,
#   'oneway': True,
#   'lanes': '2',
#   'ref': 'R24',
#   'name': 'Albertina Sisulu Road',
#   'highway': 'primary',
#   'maxspeed': '60',
#   'reversed': False,
#   'length': 75.369},
#  {'osmid': 23060550,
#   'lanes': '2',
#   'name': 'Emerald Street',
#   'highway': 'residential',
#   'oneway': False,
#   'reversed': True,
#   'length': 201.117},
#  {'osmid': 23060551,
#   'lanes': '2',
#   'name': 'Durham Street',
#   'highway': 'residential',
#   'oneway': False,
#   'reversed': True,
#   'length': 188.262},
#  {'osmid': 23060552,
#   'lanes': '2',
#   'name': 'Dasher Street',
#   'highway': 'residential',
#   'oneway': False,
#   'reversed': True,
#   'length': 162.999},
#  {'osmid': 23060553,
#   'lanes': '2',
#   'name': 'Ferret Street',
#   'highway': 'residential',
#   'oneway': False,
#   'reversed': True,
#   'length': 208.594,
#   'geometry': <LINESTRING (28.081 -26.195, 28.081 -26.194, 28.08 -26.193)>},
#  {'osmid': 87361206,
#   'lanes': '4',
#   'ref': 'R24',
#   'name': 'Albertina Sisulu Road',
#   'highway': 'primary',
#   'maxspeed': '60',
#   'oneway': False,
#   'reversed': False,
#   'length': 72.632},
#  {'osmid': 87361206,
#   'lanes': '4',
#   'ref': 'R24',
#   'name': 'Albertina Sisulu Road',
#   'highway': 'primary',
#   'maxspeed': '60',
#   'oneway': False,
#   'reversed': True,
#   'length': 65.899},
#  {'osmid': 23060554,
#   'lanes': '2',
#   'name': 'Flora Street',
#   'highway': 'residential',
#   'oneway': False,
#   'reversed': False,
#   'length': 159.176,
#   'geometry': <LINESTRING (28.081 -26.193, 28.081 -26.194, 28.081 -26.194)>},
#  {'osmid': 23060554,
#   'lanes': '2',
#   'name': 'Flora Street',
#   'highway': 'residential',
#   'oneway': False,
#   'reversed': True,
#   'length': 159.176,
#   'geometry': <LINESTRING (28.081 -26.194, 28.081 -26.194, 28.081 -26.193)>},
#  {'osmid': 87361206,
#   'lanes': '4',
#   'ref': 'R24',
#   'name': 'Albertina Sisulu Road',
#   'highway': 'primary',
#   'maxspeed': '60',
#   'oneway': False,
#   'reversed': False,
#   'length': 43.005},
#  {'osmid': 87361206,
#   'lanes': '4',
#   'ref': 'R24',
#   'name': 'Albertina Sisulu Road',
#   'highway': 'primary',
#   'maxspeed': '60',
#   'oneway': False,
#   'reversed': True,
#   'length': 72.632},
#  {'osmid': 23060555,
#   'lanes': '2',
#   'name': 'Spanker Street',
#   'highway': 'residential',
#   'oneway': False,
#   'reversed': False,
#   'length': 128.07,
#   'geometry': <LINESTRING (28.081 -26.193, 28.082 -26.193, 28.082 -26.194)>},
#  {'osmid': 23060555,
#   'lanes': '2',
#   'name': 'Spanker Street',
#   'highway': 'residential',
#   'oneway': False,
#   'reversed': True,
#   'length': 128.07,
#   'geometry': <LINESTRING (28.082 -26.194, 28.082 -26.193, 28.081 -26.193)>},
#  {'osmid': 87361206,
#   'lanes': '4',
#   'ref': 'R24',
#   'name': 'Albertina Sisulu Road',
#   'highway': 'primary',
#   'maxspeed': '60',
#   'oneway': False,
#   'reversed': False,
#   'length': 74.755},
#  {'osmid': 87361206,
#   'lanes': '4',
#   'ref': 'R24',
#   'name': 'Albertina Sisulu Road',
#   'highway': 'primary',
#   'maxspeed': '60',
#   'oneway': False,
#   'reversed': True,
#   'length': 27.299},
#  {'osmid': 23060556,
#   'lanes': '2',
#   'name': 'Saint George Street',
#   'highway': 'residential',
#   'oneway': False,
#   'reversed': False,
#   'length': 78.42099999999999,
#   'geometry': <LINESTRING (28.082 -26.192, 28.082 -26.193, 28.082 -26.193)>},
#  {'osmid': 23060556,
#   'lanes': '2',
#   'name': 'Saint George Street',
#   'highway': 'residential',
#   'oneway': False,
#   'reversed': True,
#   'length': 78.42099999999999,
#   'geometry': <LINESTRING (28.082 -26.193, 28.082 -26.193, 28.082 -26.192)>},
#  {'osmid': 87361206,
#   'lanes': '4',
#   'ref': 'R24',
#   'name': 'Albertina Sisulu Road',
#   'highway': 'primary',
#   'maxspeed': '60',
#   'oneway': False,
#   'reversed': True,
#   'length': 74.755},
#  {'osmid': 23060558,
#   'lanes': '2',
#   'name': 'Renown Street',
#   'highway': 'residential',
#   'oneway': False,
#   'reversed': False,
#   'length': 70.19,
#   'geometry': <LINESTRING (28.083 -26.192, 28.083 -26.192, 28.083 -26.193)>},
#  {'osmid': 87361206,
#   'lanes': '4',
#   'ref': 'R24',
#   'name': 'Albertina Sisulu Road',
#   'highway': 'primary',
#   'maxspeed': '60',
#   'oneway': False,
#   'reversed': False,
#   'length': 66.76,
#   'geometry': <LINESTRING (28.083 -26.192, 28.083 -26.192, 28.083 -26.192)>},
#  {'osmid': 23060558,
#   'lanes': '2',
#   'name': 'Renown Street',
#   'highway': 'residential',
#   'oneway': False,
#   'reversed': True,
#   'length': 70.19,
#   'geometry': <LINESTRING (28.083 -26.193, 28.083 -26.192, 28.083 -26.192)>},
#  {'osmid': 87361206,
#   'lanes': '4',
#   'ref': 'R24',
#   'name': 'Albertina Sisulu Road',
#   'highway': 'primary',
#   'maxspeed': '60',
#   'oneway': False,
#   'reversed': False,
#   'length': 75.174},
#  {'osmid': 23060559,
#   'lanes': '2',
#   'name': 'Hero Street',
#   'highway': 'residential',
#   'oneway': False,
#   'reversed': False,
#   'length': 66.7,
#   'geometry': <LINESTRING (28.083 -26.192, 28.084 -26.192, 28.084 -26.192)>},
#  {'osmid': 87361206,
#   'lanes': '4',
#   'ref': 'R24',
#   'name': 'Albertina Sisulu Road',
#   'highway': 'primary',
#   'maxspeed': '60',
#   'oneway': False,
#   'reversed': True,
#   'length': 66.76,
#   'geometry': <LINESTRING (28.083 -26.192, 28.083 -26.192, 28.083 -26.192)>},
#  {'osmid': 23060559,
#   'lanes': '2',
#   'name': 'Hero Street',
#   'highway': 'residential',
#   'oneway': False,
#   'reversed': True,
#   'length': 66.7,
#   'geometry': <LINESTRING (28.084 -26.192, 28.084 -26.192, 28.083 -26.192)>},
#  {'osmid': 23060560,
#   'lanes': '2',
#   'name': 'Cressey Street',
#   'highway': 'residential',
#   'oneway': False,
#   'reversed': True,
#   'length': 182.275},
#  {'osmid': 53746394,
#   'lanes': '2',
#   'name': 'Norfolk Road',
#   'highway': 'residential',
#   'oneway': False,
#   'reversed': False,
#   'length': 20.586},
#  {'osmid': 23060561,
#   'lanes': '2',
#   'name': 'Cambrian Street',
#   'highway': 'residential',
#   'oneway': False,
#   'reversed': True,
#   'length': 240.592,
#   'geometry': <LINESTRING (28.076 -26.197, 28.076 -26.196, 28.076 -26.195)>},
#  {'osmid': 53746394,
#   'lanes': '2',
#   'name': 'Norfolk Road',
#   'highway': 'residential',
#   'oneway': False,
#   'reversed': True,
#   'length': 53.567,
#   'geometry': <LINESTRING (28.076 -26.197, 28.076 -26.197, 28.076 -26.197)>},
#  {'osmid': 23327780,
#   'lanes': '2',
#   'name': 'Somerset Road',
#   'highway': 'residential',
#   'oneway': False,
#   'reversed': True,
#   'length': 193.229},
#  {'osmid': 34036206,
#   'oneway': False,
#   'lanes': '2',
#   'name': 'Kennet Street',
#   'highway': 'residential',
#   'reversed': True,
#   'length': 68.956},
#  {'osmid': 34036206,
#   'oneway': False,
#   'lanes': '2',
#   'name': 'Kennet Street',
#   'highway': 'residential',
#   'reversed': False,
#   'length': 86.11099999999999,
#   'geometry': <LINESTRING (28.091 -26.198, 28.091 -26.198, 28.091 -26.197)>},
#  {'osmid': 34035829,
#   'oneway': False,
#   'lanes': '2',
#   'name': 'Protea Street',
#   'highway': 'residential',
#   'reversed': False,
#   'length': 145.998},
#  {'osmid': 12047368,
#   'oneway': False,
#   'lanes': '2',
#   'name': 'Cumberland Road',
#   'highway': 'tertiary',
#   'reversed': False,
#   'length': 316.395,
#   'geometry': <LINESTRING (28.103 -26.187, 28.103 -26.187, 28.102 -26.188, 28.1 -26.189, 2...>},
#  {'osmid': 12047368,
#   'oneway': False,
#   'lanes': '2',
#   'name': 'Cumberland Road',
#   'highway': 'tertiary',
#   'reversed': False,
#   'length': 159.45},
#  {'osmid': 12047368,
#   'oneway': False,
#   'lanes': '2',
#   'name': 'Cumberland Road',
#   'highway': 'tertiary',
#   'reversed': True,
#   'length': 222.711,
#   'geometry': <LINESTRING (28.097 -26.19, 28.099 -26.189, 28.099 -26.189)>},
#  {'osmid': 12047368,
#   'oneway': False,
#   'lanes': '2',
#   'name': 'Cumberland Road',
#   'highway': 'tertiary',
#   'reversed': True,
#   'length': 86.233,
#   'geometry': <LINESTRING (28.089 -26.192, 28.089 -26.192, 28.09 -26.192)>},
#  {'osmid': 722282575,
#   'oneway': True,
#   'lanes': '1',
#   'name': 'Cumberland Road',
#   'highway': 'tertiary',
#   'reversed': False,
#   'length': 38.357,
#   'geometry': <LINESTRING (28.089 -26.192, 28.089 -26.192, 28.089 -26.192, 28.089 -26.192,...>},
#  {'osmid': 12047368,
#   'oneway': False,
#   'lanes': '2',
#   'name': 'Cumberland Road',
#   'highway': 'tertiary',
#   'reversed': False,
#   'length': 46.039,
#   'geometry': <LINESTRING (28.094 -26.191, 28.094 -26.191, 28.094 -26.191, 28.094 -26.191)>},
#  {'osmid': 12047368,
#   'oneway': False,
#   'lanes': '2',
#   'name': 'Cumberland Road',
#   'highway': 'tertiary',
#   'reversed': True,
#   'length': 190.429,
#   'geometry': <LINESTRING (28.094 -26.191, 28.094 -26.191, 28.096 -26.19)>},
#  {'osmid': 1120014745,
#   'lanes': '2',
#   'name': 'Montague Street',
#   'highway': 'unclassified',
#   'oneway': False,
#   'reversed': False,
#   'length': 39.131,
#   'geometry': <LINESTRING (28.094 -26.191, 28.094 -26.191, 28.094 -26.191, 28.094 -26.192,...>},
#  {'osmid': 26372355,
#   'lanes': '2',
#   'name': '5th Street',
#   'highway': 'tertiary',
#   'oneway': False,
#   'reversed': True,
#   'length': 11.372},
#  {'osmid': 616783617,
#   'oneway': True,
#   'lanes': '1',
#   'name': 'Kitchener Avenue',
#   'highway': 'secondary',
#   'reversed': False,
#   'length': 27.461000000000002,
#   'geometry': <LINESTRING (28.087 -26.191, 28.087 -26.191, 28.087 -26.191, 28.087 -26.191)>},
#  {'osmid': 87361206,
#   'lanes': '4',
#   'ref': 'R24',
#   'name': 'Albertina Sisulu Road',
#   'highway': 'primary',
#   'maxspeed': '60',
#   'oneway': False,
#   'reversed': False,
#   'length': 40.507},
#  {'osmid': 87361206,
#   'lanes': '4',
#   'ref': 'R24',
#   'name': 'Albertina Sisulu Road',
#   'highway': 'primary',
#   'maxspeed': '60',
#   'oneway': False,
#   'reversed': True,
#   'length': 25.992},
#  {'osmid': 26372454,
#   'lanes': '2',
#   'name': 'Tyne Street',
#   'highway': 'residential',
#   'oneway': False,
#   'reversed': False,
#   'length': 72.222,
#   'geometry': <LINESTRING (28.084 -26.192, 28.084 -26.192, 28.084 -26.192)>},
#  {'osmid': 26372461,
#   'lanes': '2',
#   'name': 'Cavan Street',
#   'highway': 'residential',
#   'oneway': False,
#   'reversed': False,
#   'length': 88.156,
#   'geometry': <LINESTRING (28.085 -26.192, 28.085 -26.192, 28.085 -26.191)>},
#  {'osmid': 26372476,
#   'lanes': '2',
#   'name': 'Jupiter Street',
#   'highway': 'residential',
#   'oneway': False,
#   'reversed': False,
#   'length': 133.484,
#   'geometry': <LINESTRING (28.086 -26.192, 28.086 -26.192, 28.086 -26.191)>},
#  {'osmid': 4339842,
#   'lanes': '4',
#   'ref': 'R24',
#   'name': 'Kitchener Avenue',
#   'highway': 'primary',
#   'oneway': False,
#   'reversed': False,
#   'length': 6.9},
#  {'osmid': 4339842,
#   'lanes': '4',
#   'ref': 'R24',
#   'name': 'Kitchener Avenue',
#   'highway': 'primary',
#   'oneway': False,
#   'reversed': True,
#   'length': 71.722},
#  {'osmid': 26372476,
#   'lanes': '2',
#   'name': 'Jupiter Street',
#   'highway': 'residential',
#   'oneway': False,
#   'reversed': True,
#   'length': 133.484,
#   'geometry': <LINESTRING (28.086 -26.191, 28.086 -26.192, 28.086 -26.192)>},
#  {'osmid': 26372480,
#   'oneway': False,
#   'lanes': '2',
#   'name': 'Magnet Street',
#   'highway': 'residential',
#   'reversed': False,
#   'length': 128.087,
#   'geometry': <LINESTRING (28.087 -26.192, 28.087 -26.192, 28.087 -26.191)>},
#  {'osmid': 722259075,
#   'oneway': False,
#   'lanes': '2',
#   'name': 'Kitchener Avenue',
#   'highway': 'secondary',
#   'reversed': False,
#   'length': 7.169},
#  {'osmid': 722259075,
#   'oneway': False,
#   'lanes': '2',
#   'name': 'Kitchener Avenue',
#   'highway': 'secondary',
#   'reversed': True,
#   'length': 67.717},
#  {'osmid': 26372480,
#   'oneway': False,
#   'lanes': '2',
#   'name': 'Magnet Street',
#   'highway': 'residential',
#   'reversed': True,
#   'length': 128.087,
#   'geometry': <LINESTRING (28.087 -26.191, 28.087 -26.192, 28.087 -26.192)>},
#  {'osmid': 4339842,
#   'lanes': '4',
#   'ref': 'R24',
#   'name': 'Kitchener Avenue',
#   'highway': 'primary',
#   'oneway': False,
#   'reversed': False,
#   'length': 71.722},
#  {'osmid': 87361206,
#   'lanes': '4',
#   'ref': 'R24',
#   'name': 'Albertina Sisulu Road',
#   'highway': 'primary',
#   'maxspeed': '60',
#   'oneway': False,
#   'reversed': True,
#   'length': 45.163},
#  {'osmid': 12070124,
#   'oneway': False,
#   'lanes': '4',
#   'ref': 'R22',
#   'name': 'Langermann Drive',
#   'highway': 'secondary',
#   'reversed': True,
#   'length': 78.969},
#  {'osmid': 625102379,
#   'lanes': '4',
#   'name': 'Milner Crescent',
#   'highway': 'secondary',
#   'oneway': False,
#   'reversed': False,
#   'length': 74.739},
#  {'osmid': 34035833,
#   'lanes': '2',
#   'name': 'Ocean Street',
#   'highway': 'residential',
#   'oneway': False,
#   'reversed': False,
#   'length': 301.306,
#   'geometry': <LINESTRING (28.101 -26.193, 28.102 -26.194, 28.103 -26.195)>},
#  {'osmid': 34035833,
#   'lanes': '2',
#   'name': 'Ocean Street',
#   'highway': 'residential',
#   'oneway': False,
#   'reversed': True,
#   'length': 231.727,
#   'geometry': <LINESTRING (28.101 -26.193, 28.1 -26.191, 28.1 -26.191)>},
#  {'osmid': 34654149,
#   'lanes': '2',
#   'name': 'Albermarle Street',
#   'highway': 'residential',
#   'oneway': False,
#   'reversed': True,
#   'length': 127.455,
#   'geometry': <LINESTRING (28.075 -26.201, 28.074 -26.2, 28.074 -26.2)>},
#  {'osmid': 624806811,
#   'lanes': '4',
#   'name': 'Roberts Avenue',
#   'highway': 'secondary',
#   'oneway': False,
#   'reversed': True,
#   'length': 72.824,
#   'geometry': <LINESTRING (28.075 -26.201, 28.075 -26.201, 28.075 -26.201)>},
#  {'osmid': 34035710,
#   'lanes': '2',
#   'name': 'Devon Road',
#   'highway': 'residential',
#   'oneway': False,
#   'reversed': True,
#   'length': 253.34},
#  {'osmid': 12071997,
#   'lanes': '2',
#   'name': 'Sovereign Street',
#   'highway': 'tertiary',
#   'oneway': False,
#   'reversed': False,
#   'length': 110.81700000000001,
#   'geometry': <LINESTRING (28.12 -26.197, 28.12 -26.196, 28.12 -26.196, 28.12 -26.196)>},
#  {'osmid': 12071997,
#   'lanes': '2',
#   'name': 'Sovereign Street',
#   'highway': 'tertiary',
#   'oneway': False,
#   'reversed': True,
#   'length': 65.47500000000001,
#   'geometry': <LINESTRING (28.12 -26.197, 28.12 -26.197, 28.12 -26.197)>},
#  {'osmid': 12071997,
#   'lanes': '2',
#   'name': 'Sovereign Street',
#   'highway': 'tertiary',
#   'oneway': False,
#   'reversed': True,
#   'length': 7.404},
#  {'osmid': 12071997,
#   'lanes': '2',
#   'name': 'Sovereign Street',
#   'highway': 'tertiary',
#   'oneway': False,
#   'reversed': False,
#   'length': 65.47500000000001,
#   'geometry': <LINESTRING (28.12 -26.197, 28.12 -26.197, 28.12 -26.197)>},
#  {'osmid': 12071997,
#   'lanes': '2',
#   'name': 'Sovereign Street',
#   'highway': 'tertiary',
#   'oneway': False,
#   'reversed': False,
#   'length': 77.756},
#  {'osmid': 12071997,
#   'lanes': '2',
#   'name': 'Sovereign Street',
#   'highway': 'tertiary',
#   'oneway': False,
#   'reversed': True,
#   'length': 11.756},
#  {'osmid': 34035444,
#   'lanes': '2',
#   'name': 'Buckingham Road',
#   'highway': 'residential',
#   'oneway': False,
#   'reversed': True,
#   'length': 324.998},
#  {'osmid': 721705912,
#   'lanes': '2',
#   'name': 'Royal Oak Street',
#   'highway': 'residential',
#   'oneway': False,
#   'reversed': True,
#   'length': 146.093},
#  {'osmid': 34035503,
#   'lanes': '2',
#   'name': 'Nottingham Road',
#   'highway': 'residential',
#   'oneway': False,
#   'reversed': False,
#   'length': 393.38300000000004,
#   'geometry': <LINESTRING (28.113 -26.19, 28.111 -26.191, 28.11 -26.192)>},
#  {'osmid': [721705912, 54649210],
#   'lanes': '2',
#   'name': ['Royal Oak Street', 'Westmoreland Road'],
#   'highway': 'residential',
#   'oneway': False,
#   'reversed': False,
#   'length': 201.12599999999998,
#   'geometry': <LINESTRING (28.113 -26.19, 28.113 -26.189, 28.113 -26.189, 28.113 -26.189, ...>},
#  {'osmid': 54649210,
#   'lanes': '2',
#   'name': 'Westmoreland Road',
#   'highway': 'residential',
#   'oneway': False,
#   'reversed': False,
#   'length': 398.561},
#  {'osmid': 54649210,
#   'lanes': '2',
#   'name': 'Westmoreland Road',
#   'highway': 'residential',
#   'oneway': False,
#   'reversed': True,
#   'length': 334.799},
#  {'osmid': 496129466,
#   'lanes': '2',
#   'ref': 'M33',
#   'name': 'Queen Street',
#   'highway': 'tertiary',
#   'oneway': False,
#   'reversed': True,
#   'length': 146.24},
#  {'osmid': [496129466, 624791805],
#   'lanes': ['3', '2'],
#   'ref': 'M33',
#   'name': 'Queen Street',
#   'highway': 'tertiary',
#   'oneway': False,
#   'reversed': False,
#   'length': 150.38099999999997,
#   'geometry': <LINESTRING (28.109 -26.191, 28.109 -26.19, 28.109 -26.19, 28.109 -26.19, 28...>},
#  {'osmid': 34035782,
#   'oneway': False,
#   'lanes': '2',
#   'name': 'Protea Street',
#   'highway': 'residential',
#   'reversed': False,
#   'length': 145.264},
#  {'osmid': 34035782,
#   'oneway': False,
#   'lanes': '2',
#   'name': 'Protea Street',
#   'highway': 'residential',
#   'reversed': True,
#   'length': 156.146},
#  {'osmid': 54649210,
#   'lanes': '2',
#   'name': 'Westmoreland Road',
#   'highway': 'residential',
#   'oneway': False,
#   'reversed': True,
#   'length': 398.561},
#  {'osmid': 34035503,
#   'lanes': '2',
#   'name': 'Nottingham Road',
#   'highway': 'residential',
#   'oneway': False,
#   'reversed': True,
#   'length': 79.431},
#  {'osmid': 34035966,
#   'oneway': False,
#   'lanes': '2',
#   'name': 'Nile Street',
#   'highway': 'residential',
#   'reversed': True,
#   'length': 6.642},
#  {'osmid': 34035966,
#   'oneway': False,
#   'lanes': '2',
#   'name': 'Nile Street',
#   'highway': 'residential',
#   'reversed': False,
#   'length': 208.99900000000002,
#   'geometry': <LINESTRING (28.099 -26.197, 28.099 -26.196, 28.098 -26.195)>},
#  {'osmid': 34035514,
#   'lanes': '2',
#   'name': 'Derby Road',
#   'highway': 'residential',
#   'oneway': False,
#   'reversed': False,
#   'length': 393.601},
#  {'osmid': 496129467,
#   'lanes': '2',
#   'name': 'Royal Oak Street',
#   'highway': 'residential',
#   'oneway': False,
#   'reversed': True,
#   'length': 145.905},
#  {'osmid': 721705912,
#   'lanes': '2',
#   'name': 'Royal Oak Street',
#   'highway': 'residential',
#   'oneway': False,
#   'reversed': False,
#   'length': 146.093},
#  {'osmid': 34035514,
#   'lanes': '2',
#   'name': 'Derby Road',
#   'highway': 'residential',
#   'oneway': False,
#   'reversed': False,
#   'length': 218.476,
#   'geometry': <LINESTRING (28.1 -26.198, 28.099 -26.198, 28.099 -26.198, 28.098 -26.198)>},
#  {'osmid': 34035514,
#   'lanes': '2',
#   'name': 'Derby Road',
#   'highway': 'residential',
#   'oneway': False,
#   'reversed': True,
#   'length': 28.367,
#   'geometry': <LINESTRING (28.1 -26.198, 28.1 -26.198, 28.1 -26.198, 28.1 -26.198)>},
#  {'osmid': 34035966,
#   'oneway': False,
#   'lanes': '2',
#   'name': 'Nile Street',
#   'highway': 'residential',
#   'reversed': False,
#   'length': 115.48599999999999,
#   'geometry': <LINESTRING (28.1 -26.198, 28.1 -26.198, 28.1 -26.198, 28.1 -26.197, 28.099 ...>},
#  {'osmid': 597485087,
#   'lanes': '2',
#   'highway': 'residential',
#   'oneway': False,
#   'reversed': False,
#   'length': 35.108,
#   'geometry': <LINESTRING (28.1 -26.198, 28.1 -26.198, 28.1 -26.198, 28.1 -26.198, 28.1 -2...>},
#  {'osmid': 34035993,
#   'lanes': '2',
#   'name': 'Marathon Street',
#   'highway': 'residential',
#   'oneway': False,
#   'reversed': False,
#   'length': 66.207},
#  {'osmid': 34035993,
#   'lanes': '2',
#   'name': 'Marathon Street',
#   'highway': 'residential',
#   'oneway': False,
#   'reversed': True,
#   'length': 110.001},
#  {'osmid': 34035514,
#   'lanes': '2',
#   'name': 'Derby Road',
#   'highway': 'residential',
#   'oneway': False,
#   'reversed': True,
#   'length': 218.476,
#   'geometry': <LINESTRING (28.098 -26.198, 28.099 -26.198, 28.099 -26.198, 28.1 -26.198)>},
#  {'osmid': 12072035,
#   'oneway': False,
#   'lanes': '2',
#   'name': 'Leicester Road',
#   'highway': 'residential',
#   'reversed': False,
#   'length': 418.866},
#  {'osmid': 34035522,
#   'lanes': '2',
#   'name': 'Leicester Road',
#   'highway': 'residential',
#   'oneway': False,
#   'reversed': False,
#   'length': 394.417},
#  {'osmid': 496129467,
#   'lanes': '2',
#   'name': 'Royal Oak Street',
#   'highway': 'residential',
#   'oneway': False,
#   'reversed': False,
#   'length': 145.905},
#  {'osmid': 496129467,
#   'lanes': '2',
#   'name': 'Royal Oak Street',
#   'highway': 'residential',
#   'oneway': False,
#   'reversed': True,
#   'length': 146.204},
#  {'osmid': 34035522,
#   'lanes': '2',
#   'name': 'Leicester Road',
#   'highway': 'residential',
#   'oneway': False,
#   'reversed': True,
#   'length': 69.62},
#  {'osmid': 12071997,
#   'lanes': '2',
#   'name': 'Sovereign Street',
#   'highway': 'tertiary',
#   'oneway': False,
#   'reversed': False,
#   'length': 44.441},
#  {'osmid': 34035536,
#   'lanes': '2',
#   'name': 'Highland Road',
#   'highway': 'residential',
#   'oneway': False,
#   'reversed': False,
#   'length': 381.798},
#  {'osmid': 12071997,
#   'lanes': '2',
#   'name': 'Sovereign Street',
#   'highway': 'tertiary',
#   'oneway': False,
#   'reversed': True,
#   'length': 27.172,
#   'geometry': <LINESTRING (28.119 -26.192, 28.119 -26.192, 28.119 -26.192)>},
#  {'osmid': 34035536,
#   'lanes': '2',
#   'name': 'Highland Road',
#   'highway': 'residential',
#   'oneway': False,
#   'reversed': False,
#   'length': 393.642},
#  {'osmid': 34035536,
#   'lanes': '2',
#   'name': 'Highland Road',
#   'highway': 'residential',
#   'oneway': False,
#   'reversed': True,
#   'length': 381.798},
#  {'osmid': 496129467,
#   'lanes': '2',
#   'name': 'Royal Oak Street',
#   'highway': 'residential',
#   'oneway': False,
#   'reversed': False,
#   'length': 146.204},
#  {'osmid': 496129467,
#   'lanes': '2',
#   'name': 'Royal Oak Street',
#   'highway': 'residential',
#   'oneway': False,
#   'reversed': True,
#   'length': 146.14,
#   'geometry': <LINESTRING (28.115 -26.194, 28.116 -26.194, 28.116 -26.194, 28.116 -26.195)>},
#  {'osmid': 720132681,
#   'lanes': '2',
#   'name': 'Mars Street',
#   'highway': 'residential',
#   'oneway': False,
#   'reversed': False,
#   'length': 68.697},
#  {'osmid': [34035536, 34036200],
#   'lanes': '2',
#   'name': 'Highland Road',
#   'highway': 'residential',
#   'oneway': False,
#   'reversed': False,
#   'length': 383.219,
#   'geometry': <LINESTRING (28.096 -26.199, 28.096 -26.199, 28.096 -26.2, 28.096 -26.2, 28....>},
#  {'osmid': 34035536,
#   'lanes': '2',
#   'name': 'Highland Road',
#   'highway': 'residential',
#   'oneway': False,
#   'reversed': True,
#   'length': 203.55700000000002,
#   'geometry': <LINESTRING (28.096 -26.199, 28.096 -26.199, 28.096 -26.199, 28.096 -26.199,...>},
#  {'osmid': 176501420,
#   'oneway': True,
#   'lanes': '1',
#   'name': 'Queen Street',
#   'highway': 'tertiary',
#   'reversed': False,
#   'length': 5.427},
#  {'osmid': 176501402,
#   'oneway': True,
#   'lanes': '1',
#   'ref': 'M33',
#   'name': 'Pandora Road',
#   'highway': 'tertiary',
#   'reversed': False,
#   'length': 44.056,
#   'geometry': <LINESTRING (28.113 -26.198, 28.113 -26.198, 28.113 -26.198, 28.113 -26.198,...>},
#  {'osmid': 34035668,
#   'lanes': '2',
#   'name': 'Pandora Road',
#   'highway': 'residential',
#   'oneway': False,
#   'reversed': True,
#   'length': 4.565},
#  {'osmid': 34035668,
#   'lanes': '2',
#   'name': 'Pandora Road',
#   'highway': 'residential',
#   'oneway': False,
#   'reversed': False,
#   'length': 249.856,
#   'geometry': <LINESTRING (28.113 -26.198, 28.113 -26.198, 28.11 -26.198)>},
#  {'osmid': 616779451,
#   'oneway': True,
#   'lanes': '1',
#   'name': 'Queen Street',
#   'highway': 'tertiary',
#   'reversed': False,
#   'length': 28.614,
#   'geometry': <LINESTRING (28.113 -26.198, 28.113 -26.198, 28.113 -26.198, 28.113 -26.198,...>},
#  {'osmid': 720132681,
#   'lanes': '2',
#   'name': 'Mars Street',
#   'highway': 'residential',
#   'oneway': False,
#   'reversed': True,
#   'length': 68.697},
#  {'osmid': 12069308,
#   'lanes': '2',
#   'name': 'Pandora Road',
#   'highway': 'tertiary',
#   'oneway': False,
#   'reversed': False,
#   'length': 68.76},
#  {'osmid': 12069308,
#   'lanes': '2',
#   'name': 'Pandora Road',
#   'highway': 'tertiary',
#   'oneway': False,
#   'reversed': True,
#   'length': 28.037},
#  {'osmid': [34035668, 54649222],
#   'lanes': '2',
#   'name': 'Pandora Road',
#   'highway': 'residential',
#   'oneway': False,
#   'reversed': False,
#   'length': 207.84599999999998,
#   'geometry': <LINESTRING (28.11 -26.198, 28.11 -26.198, 28.11 -26.198, 28.109 -26.198, 28...>},
#  {'osmid': 34035668,
#   'lanes': '2',
#   'name': 'Pandora Road',
#   'highway': 'residential',
#   'oneway': False,
#   'reversed': True,
#   'length': 249.856,
#   'geometry': <LINESTRING (28.11 -26.198, 28.113 -26.198, 28.113 -26.198)>},
#  {'osmid': 34035502,
#   'lanes': '2',
#   'name': 'Royal Oak Street',
#   'highway': 'residential',
#   'oneway': False,
#   'reversed': False,
#   'length': 72.241},
#  {'osmid': 34035502,
#   'lanes': '2',
#   'name': 'Royal Oak Street',
#   'highway': 'residential',
#   'oneway': False,
#   'reversed': True,
#   'length': 26.866},
#  {'osmid': 34035710,
#   'lanes': '2',
#   'name': 'Devon Road',
#   'highway': 'residential',
#   'oneway': False,
#   'reversed': False,
#   'length': 253.34},
#  {'osmid': 34035710,
#   'lanes': '2',
#   'name': 'Devon Road',
#   'highway': 'residential',
#   'oneway': False,
#   'reversed': True,
#   'length': 46.575},
#  {'osmid': 12069308,
#   'lanes': '2',
#   'name': 'Pandora Road',
#   'highway': 'tertiary',
#   'oneway': False,
#   'reversed': True,
#   'length': 102.672},
#  {'osmid': 34035739,
#   'lanes': '2',
#   'name': 'Rory Lane',
#   'highway': 'residential',
#   'oneway': False,
#   'reversed': False,
#   'length': 186.212},
#  {'osmid': 12069308,
#   'lanes': '2',
#   'name': 'Pandora Road',
#   'highway': 'tertiary',
#   'oneway': False,
#   'reversed': False,
#   'length': 104.50999999999999,
#   'geometry': <LINESTRING (28.115 -26.198, 28.115 -26.198, 28.114 -26.198)>},
#  {'osmid': 34035502,
#   'lanes': '2',
#   'name': 'Royal Oak Street',
#   'highway': 'residential',
#   'oneway': False,
#   'reversed': True,
#   'length': 72.241},
#  {'osmid': 34035739,
#   'lanes': '2',
#   'name': 'Rory Lane',
#   'highway': 'residential',
#   'oneway': False,
#   'reversed': True,
#   'length': 186.212},
#  {'osmid': 496129467,
#   'lanes': '2',
#   'name': 'Royal Oak Street',
#   'highway': 'residential',
#   'oneway': False,
#   'reversed': False,
#   'length': 71.198},
#  {'osmid': 12071997,
#   'lanes': '2',
#   'name': 'Sovereign Street',
#   'highway': 'tertiary',
#   'oneway': False,
#   'reversed': False,
#   'length': 19.069},
#  {'osmid': 12071997,
#   'lanes': '2',
#   'name': 'Sovereign Street',
#   'highway': 'tertiary',
#   'oneway': False,
#   'reversed': True,
#   'length': 38.102},
#  {'osmid': 34035742,
#   'lanes': '2',
#   'name': 'Gloucester Road',
#   'highway': 'residential',
#   'oneway': False,
#   'reversed': True,
#   'length': 288.169},
#  {'osmid': 12070124,
#   'oneway': False,
#   'lanes': '4',
#   'ref': 'R22',
#   'name': 'Langermann Drive',
#   'highway': 'secondary',
#   'reversed': False,
#   'length': 80.789},
#  {'osmid': 34035782,
#   'oneway': False,
#   'lanes': '2',
#   'name': 'Protea Street',
#   'highway': 'residential',
#   'reversed': False,
#   'length': 156.146},
#  {'osmid': 12070124,
#   'oneway': False,
#   'lanes': '4',
#   'ref': 'R22',
#   'name': 'Langermann Drive',
#   'highway': 'secondary',
#   'reversed': True,
#   'length': 262.323,
#   'geometry': <LINESTRING (28.105 -26.191, 28.106 -26.19, 28.107 -26.19, 28.107 -26.19, 28...>},
#  {'osmid': 768508349,
#   'oneway': False,
#   'lanes': '2',
#   'name': 'Protea Street',
#   'highway': 'residential',
#   'reversed': True,
#   'length': 150.386,
#   'geometry': <LINESTRING (28.105 -26.191, 28.105 -26.191, 28.104 -26.19, 28.104 -26.19)>},
#  {'osmid': 54649217,
#   'lanes': '2',
#   'name': 'Protea Street',
#   'highway': 'residential',
#   'oneway': False,
#   'reversed': True,
#   'length': 141.2},
#  {'osmid': 34035536,
#   'lanes': '2',
#   'name': 'Highland Road',
#   'highway': 'residential',
#   'oneway': False,
#   'reversed': False,
#   'length': 355.73900000000003,
#   'geometry': <LINESTRING (28.108 -26.197, 28.108 -26.197, 28.108 -26.197, 28.108 -26.197,...>},
#  {'osmid': 34035536,
#   'lanes': '2',
#   'name': 'Highland Road',
#   'highway': 'residential',
#   'oneway': False,
#   'reversed': True,
#   'length': 398.13599999999997,
#   'geometry': <LINESTRING (28.108 -26.197, 28.108 -26.197, 28.108 -26.197, 28.108 -26.197,...>},
#  {'osmid': 54649217,
#   'lanes': '2',
#   'name': 'Protea Street',
#   'highway': 'residential',
#   'oneway': False,
#   'reversed': False,
#   'length': 38.596999999999994,
#   'geometry': <LINESTRING (28.108 -26.197, 28.108 -26.197, 28.108 -26.197, 28.108 -26.197)>},
#  {'osmid': 34035514,
#   'lanes': '2',
#   'name': 'Derby Road',
#   'highway': 'residential',
#   'oneway': False,
#   'reversed': False,
#   'length': 77.946},
#  {'osmid': 34035514,
#   'lanes': '2',
#   'name': 'Derby Road',
#   'highway': 'residential',
#   'oneway': False,
#   'reversed': True,
#   'length': 80.385},
#  {'osmid': 34035826,
#   'lanes': '2',
#   'name': 'Phoenix Street',
#   'highway': 'residential',
#   'oneway': False,
#   'reversed': False,
#   'length': 144.995},
#  {'osmid': 34035826,
#   'lanes': '2',
#   'name': 'Phoenix Street',
#   'highway': 'residential',
#   'oneway': False,
#   'reversed': True,
#   'length': 228.562},
#  {'osmid': 34035897,
#   'lanes': '2',
#   'name': 'New York Road',
#   'highway': 'residential',
#   'oneway': False,
#   'reversed': True,
#   'length': 79.051,
#   'geometry': <LINESTRING (28.103 -26.189, 28.103 -26.19, 28.102 -26.19)>},
#  {'osmid': 12047368,
#   'oneway': False,
#   'lanes': '2',
#   'name': 'Cumberland Road',
#   'highway': 'tertiary',
#   'reversed': False,
#   'length': 222.711,
#   'geometry': <LINESTRING (28.099 -26.189, 28.099 -26.189, 28.097 -26.19)>},
#  {'osmid': 12047368,
#   'oneway': False,
#   'lanes': '2',
#   'name': 'Cumberland Road',
#   'highway': 'tertiary',
#   'reversed': True,
#   'length': 77.372,
#   'geometry': <LINESTRING (28.099 -26.189, 28.1 -26.189, 28.1 -26.189)>},
#  {'osmid': 34035833,
#   'lanes': '2',
#   'name': 'Ocean Street',
#   'highway': 'residential',
#   'oneway': False,
#   'reversed': False,
#   'length': 210.971,
#   'geometry': <LINESTRING (28.099 -26.189, 28.1 -26.19, 28.1 -26.191)>},
#  {'osmid': 34035514,
#   'lanes': '2',
#   'name': 'Derby Road',
#   'highway': 'residential',
#   'oneway': False,
#   'reversed': False,
#   'length': 76.063},
#  {'osmid': 34035514,
#   'lanes': '2',
#   'name': 'Derby Road',
#   'highway': 'residential',
#   'oneway': False,
#   'reversed': True,
#   'length': 77.05},
#  {'osmid': 34035833,
#   'lanes': '2',
#   'name': 'Ocean Street',
#   'highway': 'residential',
#   'oneway': False,
#   'reversed': True,
#   'length': 143.944},
#  {'osmid': 12047368,
#   'oneway': False,
#   'lanes': '2',
#   'name': 'Cumberland Road',
#   'highway': 'tertiary',
#   'reversed': False,
#   'length': 77.372,
#   'geometry': <LINESTRING (28.1 -26.189, 28.1 -26.189, 28.099 -26.189)>},
#  {'osmid': 12047368,
#   'oneway': False,
#   'lanes': '2',
#   'name': 'Cumberland Road',
#   'highway': 'tertiary',
#   'reversed': True,
#   'length': 316.39500000000004,
#   'geometry': <LINESTRING (28.1 -26.189, 28.1 -26.189, 28.102 -26.188, 28.103 -26.187, 28....>},
#  {'osmid': 34035885,
#   'oneway': False,
#   'lanes': '2',
#   'name': 'Orion Street',
#   'highway': 'residential',
#   'reversed': False,
#   'length': 211.841,
#   'geometry': <LINESTRING (28.1 -26.189, 28.1 -26.189, 28.101 -26.19)>},
#  {'osmid': 34035514,
#   'lanes': '2',
#   'name': 'Derby Road',
#   'highway': 'residential',
#   'oneway': False,
#   'reversed': False,
#   'length': 77.05},
#  {'osmid': 34035514,
#   'lanes': '2',
#   'name': 'Derby Road',
#   'highway': 'residential',
#   'oneway': False,
#   'reversed': True,
#   'length': 79.914},
#  {'osmid': 34035885,
#   'oneway': False,
#   'lanes': '2',
#   'name': 'Orion Street',
#   'highway': 'residential',
#   'reversed': True,
#   'length': 144.979},
#  {'osmid': 34035885,
#   'oneway': False,
#   'lanes': '2',
#   'name': 'Orion Street',
#   'highway': 'residential',
#   'reversed': False,
#   'length': 206.414,
#   'geometry': <LINESTRING (28.104 -26.196, 28.104 -26.196, 28.104 -26.196, 28.104 -26.197,...>},
#  {'osmid': 34035536,
#   'lanes': '2',
#   'name': 'Highland Road',
#   'highway': 'residential',
#   'oneway': False,
#   'reversed': False,
#   'length': 455.357},
#  {'osmid': 34035536,
#   'lanes': '2',
#   'name': 'Highland Road',
#   'highway': 'residential',
#   'oneway': False,
#   'reversed': True,
#   'length': 355.739,
#   'geometry': <LINESTRING (28.105 -26.198, 28.107 -26.197, 28.108 -26.197, 28.108 -26.197,...>},
#  {'osmid': 34035885,
#   'oneway': False,
#   'lanes': '2',
#   'name': 'Orion Street',
#   'highway': 'residential',
#   'reversed': True,
#   'length': 206.414,
#   'geometry': <LINESTRING (28.105 -26.198, 28.104 -26.197, 28.104 -26.196, 28.104 -26.196,...>},
#  {'osmid': 34035514,
#   'lanes': '2',
#   'name': 'Derby Road',
#   'highway': 'residential',
#   'oneway': False,
#   'reversed': False,
#   'length': 79.914},
#  {'osmid': 34035514,
#   'lanes': '2',
#   'name': 'Derby Road',
#   'highway': 'residential',
#   'oneway': False,
#   'reversed': True,
#   'length': 78.548},
#  {'osmid': 34035886,
#   'oneway': False,
#   'lanes': '2',
#   'name': 'Panther Street',
#   'highway': 'residential',
#   'reversed': False,
#   'length': 144.527},
#  {'osmid': 34035886,
#   'oneway': False,
#   'lanes': '2',
#   'name': 'Panther Street',
#   'highway': 'residential',
#   'reversed': False,
#   'length': 40.991},
#  {'osmid': 34035886,
#   'oneway': False,
#   'lanes': '2',
#   'name': 'Panther Street',
#   'highway': 'residential',
#   'reversed': True,
#   'length': 230.705},
#  {'osmid': 34035897,
#   'lanes': '2',
#   'name': 'New York Road',
#   'highway': 'residential',
#   'oneway': False,
#   'reversed': True,
#   'length': 78.326},
#  {'osmid': 34035897,
#   'lanes': '2',
#   'name': 'New York Road',
#   'highway': 'residential',
#   'oneway': False,
#   'reversed': False,
#   'length': 79.247,
#   'geometry': <LINESTRING (28.102 -26.19, 28.102 -26.19, 28.102 -26.19)>},
#  {'osmid': 34035897,
#   'lanes': '2',
#   'name': 'New York Road',
#   'highway': 'residential',
#   'oneway': False,
#   'reversed': False,
#   'length': 77.885},
#  {'osmid': 34035833,
#   'lanes': '2',
# ...
#   'oneway': False,
#   'reversed': True,
#   'length': 207.846,
#   'lanes': '2',
#   'name': 'Pandora Road',
#   'geometry': <LINESTRING (28.108 -26.197, 28.108 -26.197, 28.108 -26.198, 28.109 -26.198,...>},
#  {'osmid': 12069308,
#   'lanes': '2',
#   'name': 'Pandora Road',
#   'highway': 'tertiary',
#   'oneway': False,
#   'reversed': False,
#   'length': 55.89},
#  {'osmid': 12069308,
#   'lanes': '2',
#   'name': 'Pandora Road',
#   'highway': 'tertiary',
#   'oneway': False,
#   'reversed': True,
#   'length': 52.915},
#  {'osmid': 34035710,
#   'lanes': '2',
#   'name': 'Devon Road',
#   'highway': 'residential',
#   'oneway': False,
#   'reversed': False,
#   'length': 46.575},
#  {'osmid': 4339842,
#   'lanes': '4',
#   'ref': 'R24',
#   'name': 'Kitchener Avenue',
#   'highway': 'primary',
#   'oneway': False,
#   'reversed': True,
#   'length': 6.9},
#  {'osmid': 722259075,
#   'oneway': False,
#   'lanes': '2',
#   'name': 'Kitchener Avenue',
#   'highway': 'secondary',
#   'reversed': False,
#   'length': 67.717},
#  {'osmid': 595624359,
#   'oneway': True,
#   'lanes': '1',
#   'highway': 'secondary_link',
#   'reversed': False,
#   'length': 60.84,
#   'geometry': <LINESTRING (28.088 -26.192, 28.088 -26.192, 28.088 -26.192, 28.089 -26.192,...>},
#  {'osmid': 616783616,
#   'oneway': True,
#   'lanes': '2',
#   'name': 'Kitchener Avenue',
#   'highway': 'secondary',
#   'reversed': False,
#   'length': 46.591,
#   'geometry': <LINESTRING (28.088 -26.192, 28.088 -26.192, 28.089 -26.192)>},
#  {'osmid': 31013874,
#   'oneway': False,
#   'lanes': '4',
#   'name': 'Kitchener Avenue',
#   'highway': 'secondary',
#   'reversed': False,
#   'length': 93.826},
#  {'osmid': 31013874,
#   'oneway': False,
#   'lanes': '4',
#   'name': 'Kitchener Avenue',
#   'highway': 'secondary',
#   'reversed': True,
#   'length': 10.643},
#  {'osmid': 34036041,
#   'oneway': False,
#   'lanes': '2',
#   'name': 'Leander Street',
#   'highway': 'residential',
#   'reversed': True,
#   'length': 202.80600000000004,
#   'geometry': <LINESTRING (28.089 -26.192, 28.089 -26.192, 28.089 -26.193, 28.089 -26.193,...>},
#  {'osmid': 26372328,
#   'lanes': '2',
#   'name': '9th Avenue',
#   'highway': 'residential',
#   'oneway': False,
#   'reversed': True,
#   'length': 11.678},
#  {'osmid': 722259074,
#   'oneway': True,
#   'lanes': '1',
#   'name': 'Kitchener Avenue',
#   'highway': 'secondary',
#   'reversed': False,
#   'length': 21.229,
#   'geometry': <LINESTRING (28.087 -26.191, 28.087 -26.191, 28.087 -26.191)>},
#  {'osmid': 26372355,
#   'lanes': '2',
#   'name': '5th Street',
#   'highway': 'tertiary',
#   'oneway': False,
#   'reversed': False,
#   'length': 11.372},
#  {'osmid': 722259074,
#   'oneway': True,
#   'lanes': '1',
#   'name': 'Kitchener Avenue',
#   'highway': 'secondary',
#   'reversed': False,
#   'length': 44.878,
#   'geometry': <LINESTRING (28.087 -26.191, 28.087 -26.191, 28.087 -26.191, 28.087 -26.191)>},
#  {'osmid': 722259075,
#   'oneway': False,
#   'lanes': '2',
#   'name': 'Kitchener Avenue',
#   'highway': 'secondary',
#   'reversed': True,
#   'length': 7.169},
#  {'osmid': 616783617,
#   'oneway': True,
#   'lanes': '1',
#   'name': 'Kitchener Avenue',
#   'highway': 'secondary',
#   'reversed': False,
#   'length': 40.737,
#   'geometry': <LINESTRING (28.087 -26.191, 28.087 -26.191, 28.087 -26.191, 28.087 -26.191)>},
#  {'osmid': 722282576,
#   'oneway': True,
#   'lanes': '1',
#   'name': 'Cumberland Road',
#   'highway': 'tertiary',
#   'reversed': False,
#   'length': 10.981},
#  {'osmid': [722259074, 616783615],
#   'oneway': True,
#   'lanes': ['1', '2'],
#   'name': 'Kitchener Avenue',
#   'highway': 'secondary',
#   'reversed': False,
#   'length': 144.649,
#   'geometry': <LINESTRING (28.089 -26.192, 28.088 -26.192, 28.088 -26.192, 28.088 -26.192,...>},
#  {'osmid': 722282575,
#   'oneway': True,
#   'lanes': '1',
#   'name': 'Cumberland Road',
#   'highway': 'tertiary',
#   'reversed': False,
#   'length': 10.22},
#  {'osmid': 616783615,
#   'oneway': True,
#   'lanes': '2',
#   'name': 'Kitchener Avenue',
#   'highway': 'secondary',
#   'reversed': False,
#   'length': 7.666,
#   'geometry': <LINESTRING (28.089 -26.192, 28.089 -26.192, 28.089 -26.192)>},
#  {'osmid': 722282576,
#   'oneway': True,
#   'lanes': '1',
#   'name': 'Cumberland Road',
#   'highway': 'tertiary',
#   'reversed': False,
#   'length': 13.325,
#   'geometry': <LINESTRING (28.089 -26.192, 28.089 -26.192, 28.089 -26.192, 28.089 -26.192)>},
#  {'osmid': 722282575,
#   'oneway': True,
#   'lanes': '1',
#   'name': 'Cumberland Road',
#   'highway': 'tertiary',
#   'reversed': False,
#   'length': 10.719},
#  {'osmid': 616783616,
#   'oneway': True,
#   'lanes': '2',
#   'name': 'Kitchener Avenue',
#   'highway': 'secondary',
#   'reversed': False,
#   'length': 75.448,
#   'geometry': <LINESTRING (28.089 -26.192, 28.089 -26.192, 28.089 -26.192, 28.089 -26.192)>},
#  {'osmid': 616783616,
#   'oneway': True,
#   'lanes': '2',
#   'name': 'Kitchener Avenue',
#   'highway': 'secondary',
#   'reversed': False,
#   'length': 8.273,
#   'geometry': <LINESTRING (28.089 -26.192, 28.089 -26.192, 28.089 -26.192)>},
#  {'osmid': 722282576,
#   'oneway': True,
#   'lanes': '1',
#   'name': 'Cumberland Road',
#   'highway': 'tertiary',
#   'reversed': False,
#   'length': 31.088,
#   'geometry': <LINESTRING (28.089 -26.192, 28.089 -26.192, 28.089 -26.192, 28.089 -26.192,...>},
#  {'osmid': 722282576,
#   'oneway': True,
#   'lanes': '1',
#   'name': 'Cumberland Road',
#   'highway': 'tertiary',
#   'reversed': False,
#   'length': 10.36},
#  {'osmid': 179565396,
#   'lanes': '2',
#   'name': 'Juno Street',
#   'highway': 'tertiary',
#   'oneway': False,
#   'reversed': True,
#   'length': 192.09800000000004,
#   'geometry': <LINESTRING (28.089 -26.192, 28.089 -26.192, 28.088 -26.192, 28.088 -26.192,...>},
#  {'osmid': 624791800,
#   'lanes': '3',
#   'ref': 'M33',
#   'name': 'Queen Street',
#   'highway': 'secondary',
#   'oneway': False,
#   'reversed': True,
#   'length': 9.903},
#  {'osmid': [744422804, 744422805],
#   'oneway': True,
#   'lanes': '2',
#   'ref': 'R22',
#   'name': 'Langermann Drive',
#   'highway': 'secondary',
#   'reversed': False,
#   'length': 112.586,
#   'geometry': <LINESTRING (28.108 -26.189, 28.109 -26.189, 28.109 -26.189, 28.109 -26.189,...>},
#  {'osmid': 624791803,
#   'oneway': False,
#   'lanes': '4',
#   'ref': 'R22',
#   'name': 'Langermann Drive',
#   'highway': 'secondary',
#   'reversed': True,
#   'length': 223.226,
#   'geometry': <LINESTRING (28.109 -26.189, 28.11 -26.189, 28.111 -26.188)>},
#  {'osmid': [744422809, 624791801],
#   'oneway': True,
#   'lanes': ['3', '2'],
#   'ref': 'R22',
#   'name': 'Langermann Drive',
#   'highway': 'secondary',
#   'reversed': False,
#   'length': 111.99,
#   'geometry': <LINESTRING (28.109 -26.189, 28.109 -26.189, 28.109 -26.189, 28.109 -26.189,...>},
#  {'osmid': 12070124,
#   'oneway': False,
#   'lanes': '4',
#   'ref': 'R22',
#   'name': 'Langermann Drive',
#   'highway': 'secondary',
#   'reversed': False,
#   'length': 262.323,
#   'geometry': <LINESTRING (28.107 -26.19, 28.107 -26.19, 28.107 -26.19, 28.106 -26.19, 28....>},
#  {'osmid': [744422806, 744422807],
#   'oneway': True,
#   'lanes': ['3', '2'],
#   'ref': 'R22',
#   'name': 'Langermann Drive',
#   'highway': 'secondary',
#   'reversed': False,
#   'length': 135.31,
#   'geometry': <LINESTRING (28.107 -26.19, 28.107 -26.19, 28.107 -26.19, 28.107 -26.19, 28....>},
#  {'osmid': 34035668,
#   'lanes': '2',
#   'name': 'Pandora Road',
#   'highway': 'residential',
#   'oneway': False,
#   'reversed': False,
#   'length': 4.565},
#  {'osmid': 23060550,
#   'lanes': '2',
#   'name': 'Emerald Street',
#   'highway': 'residential',
#   'oneway': False,
#   'reversed': False,
#   'length': 7.496},
#  {'osmid': 765781195,
#   'oneway': True,
#   'lanes': '2',
#   'ref': 'R24',
#   'name': 'Albertina Sisulu Road',
#   'highway': 'primary',
#   'maxspeed': '60',
#   'reversed': False,
#   'length': 53.922},
#  {'osmid': 23060549,
#   'lanes': '2',
#   'name': 'Essex Street',
#   'highway': 'residential',
#   'oneway': False,
#   'reversed': False,
#   'length': 7.804},
#  {'osmid': 765781195,
#   'oneway': True,
#   'lanes': '2',
#   'ref': 'R24',
#   'name': 'Albertina Sisulu Road',
#   'highway': 'primary',
#   'maxspeed': '60',
#   'reversed': False,
#   'length': 12.854},
#  {'osmid': 765781195,
#   'oneway': True,
#   'lanes': '2',
#   'ref': 'R24',
#   'name': 'Albertina Sisulu Road',
#   'highway': 'primary',
#   'maxspeed': '60',
#   'reversed': False,
#   'length': 12.752},
#  {'osmid': 23060551,
#   'lanes': '2',
#   'name': 'Durham Street',
#   'highway': 'residential',
#   'oneway': False,
#   'reversed': False,
#   'length': 8.078},
#  {'osmid': 765781195,
#   'oneway': True,
#   'lanes': '2',
#   'ref': 'R24',
#   'name': 'Albertina Sisulu Road',
#   'highway': 'primary',
#   'maxspeed': '60',
#   'reversed': False,
#   'length': 75.209},
#  {'osmid': 23060552,
#   'lanes': '2',
#   'name': 'Dasher Street',
#   'highway': 'residential',
#   'oneway': False,
#   'reversed': False,
#   'length': 8.08},
#  {'osmid': 765781195,
#   'oneway': True,
#   'lanes': '2',
#   'ref': 'R24',
#   'name': 'Albertina Sisulu Road',
#   'highway': 'primary',
#   'maxspeed': '60',
#   'reversed': False,
#   'length': 67.427},
#  {'osmid': 23060545,
#   'lanes': '2',
#   'name': '1st Street',
#   'highway': 'residential',
#   'oneway': False,
#   'reversed': True,
#   'length': 7.771},
#  {'osmid': 765781195,
#   'oneway': True,
#   'lanes': '2',
#   'ref': 'R24',
#   'name': 'Albertina Sisulu Road',
#   'highway': 'primary',
#   'maxspeed': '60',
#   'reversed': False,
#   'length': 107.01599999999999,
#   'geometry': <LINESTRING (28.076 -26.194, 28.077 -26.194, 28.077 -26.194)>},
#  {'osmid': 87361206,
#   'lanes': '4',
#   'ref': 'R24',
#   'name': 'Albertina Sisulu Road',
#   'highway': 'primary',
#   'maxspeed': '60',
#   'oneway': False,
#   'reversed': False,
#   'length': 64.385},
#  {'osmid': 765781196,
#   'oneway': True,
#   'lanes': '2',
#   'ref': 'R24',
#   'name': 'Albertina Sisulu Road',
#   'highway': 'primary',
#   'maxspeed': '60',
#   'reversed': False,
#   'length': 13.815},
#  {'osmid': 23060541,
#   'lanes': '2',
#   'name': 'Lang Street',
#   'highway': 'residential',
#   'oneway': False,
#   'reversed': False,
#   'length': 6.585},
#  {'osmid': 767333415,
#   'oneway': True,
#   'lanes': '2',
#   'ref': 'R24',
#   'name': 'Albertina Sisulu Road',
#   'highway': 'primary',
#   'maxspeed': '60',
#   'reversed': False,
#   'length': 22.935},
#  {'osmid': 34654212,
#   'lanes': '2',
#   'name': 'Boxer Street',
#   'highway': 'residential',
#   'oneway': False,
#   'reversed': True,
#   'length': 113.492},
#  {'osmid': [1119541597, 767333415],
#   'oneway': True,
#   'lanes': '2',
#   'ref': 'R24',
#   'name': 'Albertina Sisulu Road',
#   'highway': 'primary',
#   'maxspeed': '60',
#   'reversed': False,
#   'length': 65.40299999999999,
#   'geometry': <LINESTRING (28.074 -26.195, 28.074 -26.195, 28.074 -26.195, 28.074 -26.196)>},
#  {'osmid': 23060560,
#   'lanes': '2',
#   'name': 'Cressey Street',
#   'highway': 'residential',
#   'oneway': False,
#   'reversed': False,
#   'length': 182.275},
#  {'osmid': 23060560,
#   'lanes': '2',
#   'name': 'Cressey Street',
#   'highway': 'residential',
#   'oneway': False,
#   'reversed': True,
#   'length': 7.026},
#  {'osmid': 767333415,
#   'oneway': True,
#   'lanes': '2',
#   'ref': 'R24',
#   'name': 'Albertina Sisulu Road',
#   'highway': 'primary',
#   'maxspeed': '60',
#   'reversed': False,
#   'length': 65.257},
#  {'osmid': 23060561,
#   'lanes': '2',
#   'name': 'Cambrian Street',
#   'highway': 'residential',
#   'oneway': False,
#   'reversed': True,
#   'length': 6.973},
#  {'osmid': 767333415,
#   'oneway': True,
#   'lanes': '2',
#   'ref': 'R24',
#   'name': 'Albertina Sisulu Road',
#   'highway': 'primary',
#   'maxspeed': '60',
#   'reversed': False,
#   'length': 76.476},
#  {'osmid': 23060561,
#   'lanes': '2',
#   'name': 'Cambrian Street',
#   'highway': 'residential',
#   'oneway': False,
#   'reversed': False,
#   'length': 240.592,
#   'geometry': <LINESTRING (28.076 -26.195, 28.076 -26.196, 28.076 -26.197)>},
#  {'osmid': 721696358,
#   'lanes': '2',
#   'name': 'Benbow Street',
#   'highway': 'residential',
#   'oneway': False,
#   'reversed': True,
#   'length': 6.243},
#  {'osmid': 767333415,
#   'oneway': True,
#   'lanes': '2',
#   'ref': 'R24',
#   'name': 'Albertina Sisulu Road',
#   'highway': 'primary',
#   'maxspeed': '60',
#   'reversed': False,
#   'length': 56.48},
#  {'osmid': 721696358,
#   'lanes': '2',
#   'name': 'Benbow Street',
#   'highway': 'residential',
#   'oneway': False,
#   'reversed': False,
#   'length': 187.655,
#   'geometry': <LINESTRING (28.075 -26.195, 28.075 -26.196, 28.076 -26.197)>},
#  {'osmid': 768272353,
#   'oneway': True,
#   'lanes': '2',
#   'ref': 'R22',
#   'name': 'Langermann Drive',
#   'highway': 'secondary',
#   'reversed': False,
#   'length': 22.858,
#   'geometry': <LINESTRING (28.114 -26.187, 28.114 -26.187, 28.113 -26.187, 28.113 -26.187)>},
#  {'osmid': 821855710,
#   'name': 'Lemur Street',
#   'highway': 'residential',
#   'oneway': False,
#   'reversed': False,
#   'length': 59.119,
#   'geometry': <LINESTRING (28.093 -26.199, 28.093 -26.199, 28.093 -26.199)>},
#  {'osmid': 34036038,
#   'lanes': '2',
#   'name': 'Ernest Road',
#   'highway': 'residential',
#   'oneway': False,
#   'reversed': False,
#   'length': 44.882},
#  {'osmid': 34036038,
#   'lanes': '2',
#   'name': 'Ernest Road',
#   'highway': 'residential',
#   'oneway': False,
#   'reversed': True,
#   'length': 34.227},
#  {'osmid': 821855710,
#   'name': 'Lemur Street',
#   'highway': 'residential',
#   'oneway': False,
#   'reversed': True,
#   'length': 59.119,
#   'geometry': <LINESTRING (28.093 -26.199, 28.093 -26.199, 28.093 -26.199)>},
#  {'osmid': 597485083,
#   'oneway': True,
#   'lanes': '1',
#   'ref': 'M33',
#   'name': 'Queen Street',
#   'highway': 'tertiary',
#   'reversed': False,
#   'length': 2.351},
#  {'osmid': 943722556,
#   'highway': 'residential',
#   'oneway': False,
#   'reversed': True,
#   'length': 140.7,
#   'geometry': <LINESTRING (28.113 -26.198, 28.113 -26.197, 28.114 -26.197, 28.114 -26.197)>},
#  {'osmid': 943722556,
#   'highway': 'residential',
#   'oneway': False,
#   'reversed': False,
#   'length': 140.7,
#   'geometry': <LINESTRING (28.114 -26.197, 28.114 -26.197, 28.113 -26.197, 28.113 -26.198)>},
#  {'osmid': 12069308,
#   'lanes': '2',
#   'name': 'Pandora Road',
#   'highway': 'tertiary',
#   'oneway': False,
#   'reversed': False,
#   'length': 4.824},
#  {'osmid': 12069308,
#   'lanes': '2',
#   'name': 'Pandora Road',
#   'highway': 'tertiary',
#   'oneway': False,
#   'reversed': True,
#   'length': 145.253},
#  {'osmid': 944095902,
#   'highway': 'residential',
#   'oneway': False,
#   'reversed': True,
#   'length': 146.852,
#   'geometry': <LINESTRING (28.119 -26.198, 28.119 -26.198, 28.119 -26.198, 28.119 -26.198,...>},
#  {'osmid': 12071997,
#   'lanes': '2',
#   'name': 'Sovereign Street',
#   'highway': 'tertiary',
#   'oneway': False,
#   'reversed': False,
#   'length': 7.404},
#  {'osmid': 12071997,
#   'lanes': '2',
#   'name': 'Sovereign Street',
#   'highway': 'tertiary',
#   'oneway': False,
#   'reversed': True,
#   'length': 78.057,
#   'geometry': <LINESTRING (28.12 -26.197, 28.12 -26.198, 28.12 -26.198)>},
#  {'osmid': 944095902,
#   'highway': 'residential',
#   'oneway': False,
#   'reversed': False,
#   'length': 146.852,
#   'geometry': <LINESTRING (28.12 -26.197, 28.119 -26.198, 28.119 -26.198, 28.119 -26.198, ...>},
#  {'osmid': 1065781353,
#   'highway': 'residential',
#   'oneway': False,
#   'reversed': True,
#   'length': 68.785,
#   'geometry': <LINESTRING (28.108 -26.195, 28.108 -26.195, 28.108 -26.195, 28.107 -26.195,...>},
#  {'osmid': 34035782,
#   'oneway': False,
#   'lanes': '2',
#   'name': 'Protea Street',
#   'highway': 'residential',
#   'reversed': False,
#   'length': 5.84},
#  {'osmid': 34035782,
#   'oneway': False,
#   'lanes': '2',
#   'name': 'Protea Street',
#   'highway': 'residential',
#   'reversed': True,
#   'length': 72.536},
#  {'osmid': 1065781353,
#   'highway': 'residential',
#   'oneway': False,
#   'reversed': False,
#   'length': 68.785,
#   'geometry': <LINESTRING (28.107 -26.195, 28.107 -26.195, 28.107 -26.195, 28.108 -26.195,...>},
#  {'osmid': 1179649581,
#   'highway': 'residential',
#   'oneway': False,
#   'reversed': True,
#   'length': 68.806},
#  {'osmid': 34036038,
#   'lanes': '2',
#   'name': 'Ernest Road',
#   'highway': 'residential',
#   'oneway': False,
#   'reversed': True,
#   'length': 54.698},
#  {'osmid': 1179649581,
#   'highway': 'residential',
#   'oneway': False,
#   'reversed': False,
#   'length': 68.806},
#  {'osmid': 34036038,
#   'lanes': '2',
#   'name': 'Ernest Road',
#   'highway': 'residential',
#   'oneway': False,
#   'reversed': False,
#   'length': 56.042,
#   'geometry': <LINESTRING (28.098 -26.197, 28.097 -26.197, 28.097 -26.197)>}]

# %%
# Define colors according to length of streets
roadCols = []

for item in data:
    if "length" in item.keys():
        if item["length"] <= 200:
            color = "#FFFFF0"             
        elif 200 < item["length"] <= 1000:
            color = "#6a0dad"  
        else:
            color = "#00FFFF"
    else:
        color = "#FFFFFF"         
    roadCols.append(color)

#Plot 
bgcolor = "#1e1e1e"
fig, ax = ox.plot_graph(kensington_graph, node_size=0, 
                        dpi = 100,bgcolor = bgcolor,
                        save = False, edge_color=roadCols,
                        edge_linewidth=1, edge_alpha=1)
fig.tight_layout(pad=0)
fig.savefig("stack.jpg", dpi=100, bbox_inches='tight', format="jpg", 
            facecolor=fig.get_facecolor(), transparent=False)

# %%
kensington_gdf = ox.graph_to_gdfs(kensington_graph, nodes=False)
print(len(kensington_gdf))
kensington_gdf.head()
# Out:
# 872
#                                           osmid lanes  ref  \
# u        v          key
# 26417799 305730224  0                  87361206     4  R24
#          288933063  0                  87361206     4  R24
#          288933328  0                  26372461     2  NaN
# 26417800 7151979247 0                  23060545     2  NaN
#          7164510312 0    [765781197, 767333415]     2  R24
#
#                                           name      highway maxspeed  oneway  \
# u        v          key
# 26417799 305730224  0    Albertina Sisulu Road      primary       60   False
#          288933063  0    Albertina Sisulu Road      primary       60   False
#          288933328  0             Cavan Street  residential      NaN   False
# 26417800 7151979247 0               1st Street  residential      NaN   False
#          7164510312 0    Albertina Sisulu Road      primary       60    True
#
#                         reversed  length  \
# u        v          key
# 26417799 305730224  0      False  45.163
#          288933063  0       True  40.507
#          288933328  0       True  88.156
# 26417800 7151979247 0      False   7.771
#          7164510312 0      False  31.393
#
#                                                                   geometry
# u        v          key
# 26417799 305730224  0    LINESTRING (28.08472 -26.19144, 28.08513 -26.1...
#          288933063  0    LINESTRING (28.08472 -26.19144, 28.08434 -26.1...
#          288933328  0    LINESTRING (28.08472 -26.19144, 28.08491 -26.1...
# 26417800 7151979247 0    LINESTRING (28.07650 -26.19444, 28.07647 -26.1...
#          7164510312 0    LINESTRING (28.07650 -26.19444, 28.07638 -26.1...

# %%
def modify_street(x):
    if "length" in x.keys():
        if x["length"] <= 200:
            x_color = "#FFFFF0"             
        elif 200 < x["length"] <= 1000:
            x_color = "#6a0dad"  
        else:
            x_color = "#00FFFF"
    else:
        x_color = "#FFFFFF"   
    x["road_color"] = x_color
    return x

# %%
kensington_gdf = kensington_gdf.apply(lambda x: modify_street(x), axis=1)
kensington_gdf
# Out:
#                                               osmid lanes  ref  \
# u           v           key
# 26417799    305730224   0                  87361206     4  R24
#             288933063   0                  87361206     4  R24
#             288933328   0                  26372461     2  NaN
# 26417800    7151979247  0                  23060545     2  NaN
#             7164510312  0    [765781197, 767333415]     2  R24
# ...                                             ...   ...  ...
# 9787389627  9787389622  0                1065781353   NaN  NaN
# 10956601309 10956601310 0                1179649581   NaN  NaN
# 10956601310 390371867   0                  34036038     2  NaN
#             10956601309 0                1179649581   NaN  NaN
#             390036534   0                  34036038     2  NaN
#
#                                               name      highway maxspeed  \
# u           v           key
# 26417799    305730224   0    Albertina Sisulu Road      primary       60
#             288933063   0    Albertina Sisulu Road      primary       60
#             288933328   0             Cavan Street  residential      NaN
# 26417800    7151979247  0               1st Street  residential      NaN
#             7164510312  0    Albertina Sisulu Road      primary       60
# ...                                            ...          ...      ...
# 9787389627  9787389622  0                      NaN  residential      NaN
# 10956601309 10956601310 0                      NaN  residential      NaN
# 10956601310 390371867   0              Ernest Road  residential      NaN
#             10956601309 0                      NaN  residential      NaN
#             390036534   0              Ernest Road  residential      NaN
#
#                              oneway reversed  length  \
# u           v           key
# 26417799    305730224   0     False    False  45.163
#             288933063   0     False     True  40.507
#             288933328   0     False     True  88.156
# 26417800    7151979247  0     False    False   7.771
#             7164510312  0      True    False  31.393
# ...                             ...      ...     ...
# 9787389627  9787389622  0     False    False  68.785
# 10956601309 10956601310 0     False     True  68.806
# 10956601310 390371867   0     False     True  54.698
#             10956601309 0     False    False  68.806
#             390036534   0     False    False  56.042
#
#                                                                       geometry  \
# u           v           key
# 26417799    305730224   0    LINESTRING (28.08472 -26.19144, 28.08513 -26.1...
#             288933063   0    LINESTRING (28.08472 -26.19144, 28.08434 -26.1...
#             288933328   0    LINESTRING (28.08472 -26.19144, 28.08491 -26.1...
# 26417800    7151979247  0    LINESTRING (28.07650 -26.19444, 28.07647 -26.1...
#             7164510312  0    LINESTRING (28.07650 -26.19444, 28.07638 -26.1...
# ...                                                                        ...
# 9787389627  9787389622  0    LINESTRING (28.10714 -26.19513, 28.10727 -26.1...
# 10956601309 10956601310 0    LINESTRING (28.09764 -26.19670, 28.09791 -26.1...
# 10956601310 390371867   0    LINESTRING (28.09791 -26.19727, 28.09842 -26.1...
#             10956601309 0    LINESTRING (28.09791 -26.19727, 28.09764 -26.1...
#             390036534   0    LINESTRING (28.09791 -26.19727, 28.09749 -26.1...
#
#                             road_color
# u           v           key
# 26417799    305730224   0      #FFFFF0
#             288933063   0      #FFFFF0
#             288933328   0      #FFFFF0
# 26417800    7151979247  0      #FFFFF0
#             7164510312  0      #FFFFF0
# ...                                ...
# 9787389627  9787389622  0      #FFFFF0
# 10956601309 10956601310 0      #FFFFF0
# 10956601310 390371867   0      #FFFFF0
#             10956601309 0      #FFFFF0
#             390036534   0      #FFFFF0
#
# [872 rows x 11 columns]

# %%
#Plot 
bgcolor = "#1e1e1e"
fig, ax = ox.plot_graph(kensington_graph, node_size=0, 
                        dpi = 100,bgcolor = bgcolor,
                        save = False, edge_color=kensington_gdf["road_color"],
                        edge_linewidth=1, edge_alpha=1)
fig.tight_layout(pad=0)
fig.savefig("stack.jpg", dpi=100, bbox_inches='tight', format="jpg", 
            facecolor=fig.get_facecolor(), transparent=False)
