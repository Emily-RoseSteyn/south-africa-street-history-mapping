# %%
import osmnx as ox
city = ox.geocode_to_gdf('South Africa')
ax = ox.project_gdf(city).plot()
_ = ax.axis('off')

# %%
G = ox.graph_from_place('City of Johannesburg, South Africa', network_type='drive')
ox.plot_graph(G)
# Out:
# (<Figure size 800x800 with 1 Axes>, <Axes: >)
